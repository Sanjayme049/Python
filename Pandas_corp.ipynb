# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjayme049/Python/blob/main/Pandas_corp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

A = pd.DataFrame({'color': ['green', 'yellow', 'red'], 'num':[1,2,3]})
A
# Out:
#     color  num
# 0   green    1
# 1  yellow    2
# 2     red    3

# %%
B = pd.DataFrame({'color': ['green', 'yellow', 'pink'], 'size':['S','M','L']})
B
# Out:
#     color size
# 0   green    S
# 1  yellow    M
# 2    pink    L

# %%
pd.merge(A, B, how='inner')
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M

# %%
pd.merge(A, B, how='outer')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2     red  3.0  NaN
# 3    pink  NaN    L

# %%
pd.merge(A, B, how='left')
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M
# 2     red    3  NaN

# %%
pd.merge(A, B, how='right')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2    pink  NaN    L
